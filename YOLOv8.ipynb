# %% [markdown]
# <a href="https://colab.research.google.com/github/thamarlambregtsehva/yolo/blob/main/YOLOv8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Mon Jun 10 20:21:40 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   44C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# %pip install ultralytics
import ultralytics
from ultralytics import YOLO
from IPython.display import display, Image
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.30 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 30.1/78.2 GB disk)

# %%
# # Create a directory for the dataset
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets
# Out:
# /content/datasets

# %%
# %cd {HOME}/datasets
# Out:
# /content/datasets

# %%
# !pip install roboflow
from roboflow import Roboflow
rf = Roboflow(api_key="0TiCKk2mRK8OmLuGPy6z")
project = rf.workspace("tt-n7yca").project("veggievision-zpu1h")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.2.30, to fix: `pip install ultralytics==8.0.196`

# %%
# !yolo task=detect mode=train model=yolov8l.pt data=/content/datasets/VeggieVision-1/data.yaml epochs=100 imgsz=640 batch=16
# Out:
# Ultralytics YOLOv8.2.30 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
project.version(1).deploy(model_type='yolov8', model_path='/content/datasets/runs/detect/train')
# Out:
# Dependency ultralytics==8.0.196 is required but found version=8.2.30, to fix: `pip install ultralytics==8.0.196`
# Would you like to continue with the wrong version of ultralytics? y/n: y
# View the status of your deployment at: https://app.roboflow.com/tt-n7yca/veggievision-zpu1h/1
# Share your model with the world at: https://universe.roboflow.com/tt-n7yca/veggievision-zpu1h/model/1

# %%
# !pip install ultralytics==8.0.196
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 631.1/631.1 kB 8.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.2.30
#     Uninstalling ultralytics-8.2.30:
#       Successfully uninstalled ultralytics-8.2.30
# ...
